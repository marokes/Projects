# %%
import pandas as pd

df=pd.read_csv('spotify.csv')

pd.options.display.max_columns = None
df
# Out:
#        Unnamed: 0                track_id  \
# 0               0  5aAx2yezTd8zXrkmtKl66Z
# 1               1  5aAx2yezTd8zXrkmtKl66Z
# 2               2  5aAx2yezTd8zXrkmtKl66Z
# 3               3  5aAx2yezTd8zXrkmtKl66Z
# 4               4  5aAx2yezTd8zXrkmtKl66Z
# ...           ...                     ...
# 42195       42195  0WSa1sucoNRcEeULlZVQXj
# 42196       42196  3Ofmpyhv5UAQ70mENzB277
# 42197       42197  4I5bvu2KDsrCg0EWHIcvul
# 42198       42198  4PEfJZpVjdclfzZ9XO8uDw
# 42199       42199  78xj07VVFK5uHTaGPIu13S
#
#                                   track_uri           artist_name  \
# 0      spotify:track:5aAx2yezTd8zXrkmtKl66Z            The Weeknd
# 1      spotify:track:5aAx2yezTd8zXrkmtKl66Z            The Weeknd
# 2      spotify:track:5aAx2yezTd8zXrkmtKl66Z            The Weeknd
# 3      spotify:track:5aAx2yezTd8zXrkmtKl66Z            The Weeknd
# 4      spotify:track:5aAx2yezTd8zXrkmtKl66Z            The Weeknd
# ...

# %%
len(df['track_id'].unique())
# Out:
# 4087

# %%
df.sort_values(['date_release'])
# Out:
#        Unnamed: 0                track_id  \
# 2087         2087  4so0Wek9Ig1p6CRCHuINwW
# 2077         2077  4so0Wek9Ig1p6CRCHuINwW
# 2078         2078  4so0Wek9Ig1p6CRCHuINwW
# 2079         2079  4so0Wek9Ig1p6CRCHuINwW
# 2080         2080  4so0Wek9Ig1p6CRCHuINwW
# ...           ...                     ...
# 42191       42191  2g1KggY9PKvsoEAOaiz4xx
# 42187       42187  6T6D9CIrHkALcHPafDFA6L
# 42185       42185  3jjBPF4NDMCU51psU8JPpR
# 42192       42192  5uEYRdEIh9Bo4fpjDd4Na9
# 42186       42186  43CIWpJaJHRcI4mUSjqgc2
#
#                                   track_uri    artist_name  \
# 2087   spotify:track:4so0Wek9Ig1p6CRCHuINwW    Bing Crosby
# 2077   spotify:track:4so0Wek9Ig1p6CRCHuINwW    Bing Crosby
# 2078   spotify:track:4so0Wek9Ig1p6CRCHuINwW    Bing Crosby
# 2079   spotify:track:4so0Wek9Ig1p6CRCHuINwW    Bing Crosby
# 2080   spotify:track:4so0Wek9Ig1p6CRCHuINwW    Bing Crosby
# ...                                     ...            ...
# ...

# %%
gnrs=pd.read_csv('genres.csv')

pd.options.display.max_columns = None
gnrs
# Out:
# C:\Users\marok\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.831   0.814    2    -7.364     1       0.4200      0.059800
# 1             0.719   0.493    8    -7.230     1       0.0794      0.401000
# 2             0.850   0.893    5    -4.783     1       0.0623      0.013800
# 3             0.476   0.781    0    -4.710     1       0.1030      0.023700
# 4             0.798   0.624    2    -7.668     1       0.2930      0.217000
# ...             ...     ...  ...       ...   ...          ...           ...
# 42300         0.528   0.693    4    -5.148     1       0.0304      0.031500
# 42301         0.517   0.768    0    -7.922     0       0.0479      0.022500
# ...

# %%
len(gnrs['genre'].unique())
# Out:
# 15

# %%
gnrs['genre'].unique()
# Out:
# array(['Dark Trap', 'Underground Rap', 'Trap Metal', 'Emo', 'Rap', 'RnB',
#        'Pop', 'Hiphop', 'techhouse', 'techno', 'trance', 'psytrance',
#        'trap', 'dnb', 'hardstyle'], dtype=object)

# %%
gnrs.rename(columns = {'id':'track_id'}, inplace = True)

gnrs
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.831   0.814    2    -7.364     1       0.4200      0.059800
# 1             0.719   0.493    8    -7.230     1       0.0794      0.401000
# 2             0.850   0.893    5    -4.783     1       0.0623      0.013800
# 3             0.476   0.781    0    -4.710     1       0.1030      0.023700
# 4             0.798   0.624    2    -7.668     1       0.2930      0.217000
# ...             ...     ...  ...       ...   ...          ...           ...
# 42300         0.528   0.693    4    -5.148     1       0.0304      0.031500
# 42301         0.517   0.768    0    -7.922     0       0.0479      0.022500
# 42302         0.361   0.821    8    -3.102     1       0.0505      0.026000
# 42303         0.477   0.921    6    -4.777     0       0.0392      0.000551
# 42304         0.529   0.945    9    -5.862     1       0.0615      0.001890
#
# ...

# %%
data=pd.merge(df, gnrs, on="track_id")

data
# Out:
#        Unnamed: 0_x                track_id  \
# 0                67  7BKLCZ1jbUBVqRi2FVlTVw
# 1                68  7BKLCZ1jbUBVqRi2FVlTVw
# 2                69  7BKLCZ1jbUBVqRi2FVlTVw
# 3                70  7BKLCZ1jbUBVqRi2FVlTVw
# 4                71  7BKLCZ1jbUBVqRi2FVlTVw
# ...             ...                     ...
# 27359         42157  1f3yAtsJtY87CTmM8RLnxf
# 27360         42158  1f3yAtsJtY87CTmM8RLnxf
# 27361         42159  1f3yAtsJtY87CTmM8RLnxf
# 27362         42175  4aarlAfLKVCTxUDNgbwhjH
# 27363         42176  4aarlAfLKVCTxUDNgbwhjH
#
#                                   track_uri          artist_name  \
# 0      spotify:track:7BKLCZ1jbUBVqRi2FVlTVw     The Chainsmokers
# 1      spotify:track:7BKLCZ1jbUBVqRi2FVlTVw     The Chainsmokers
# 2      spotify:track:7BKLCZ1jbUBVqRi2FVlTVw     The Chainsmokers
# 3      spotify:track:7BKLCZ1jbUBVqRi2FVlTVw     The Chainsmokers
# 4      spotify:track:7BKLCZ1jbUBVqRi2FVlTVw     The Chainsmokers
# ...

# %%
len(data['track_id'].unique())
# Out:
# 1033

# %%
len(data['artist_name'].unique())
# Out:
# 249

# %%
data.drop(['Unnamed: 0_x', 'track_uri', 'album_id','album_name','URL','track_href_x','analysis_url_x','acousticness_x','danceability_x','duration_ms_x','energy_x','instrumentalness_x','key_x','liveness_x','loudness_x','mode_x','speechiness_x','tempo_x','time_signature_x','valence_x','danceability_y','energy_y','key_y','loudness_y','mode_y','speechiness_y','acousticness_y','instrumentalness_y','liveness_y','valence_y','tempo_y','type','uri','track_href_y','analysis_url_y','duration_ms_y','time_signature_y','Unnamed: 0_y','title','song_name',], axis=1, inplace=True)

# %%
data
# Out:
#                      track_id          artist_name               track_name  \
# 0      7BKLCZ1jbUBVqRi2FVlTVw     The Chainsmokers                   Closer
# 1      7BKLCZ1jbUBVqRi2FVlTVw     The Chainsmokers                   Closer
# 2      7BKLCZ1jbUBVqRi2FVlTVw     The Chainsmokers                   Closer
# 3      7BKLCZ1jbUBVqRi2FVlTVw     The Chainsmokers                   Closer
# 4      7BKLCZ1jbUBVqRi2FVlTVw     The Chainsmokers                   Closer
# ...                       ...                  ...                      ...
# 27359  1f3yAtsJtY87CTmM8RLnxf              Nirvana  Smells Like Teen Spirit
# 27360  1f3yAtsJtY87CTmM8RLnxf              Nirvana  Smells Like Teen Spirit
# 27361  1f3yAtsJtY87CTmM8RLnxf              Nirvana  Smells Like Teen Spirit
# 27362  4aarlAfLKVCTxUDNgbwhjH  Megan Thee Stallion  Cry Baby (feat. DaBaby)
# 27363  4aarlAfLKVCTxUDNgbwhjH  Megan Thee Stallion  Cry Baby (feat. DaBaby)
#
# ...

# %%
genres=pd.read_csv('genre_songs.csv', encoding='latin-1')

genres
# Out:
#                      track.id                       track.name  \
# 0      7bIq1v8svANsAys7I694Up  Heaven On My Mind (with Sigala)
# 1      24ySl2hOPGCDcxBxFIqWBu  Rain On Me (with Ariana Grande)
# 2      24Yi9hE78yPEbZ4kxyoXAI            Roses - Imanbek Remix
# 3      3Be7CLdHZpyzsVijme39cW    What's Love Got to Do with It
# 4      57YMEPQhEy5F5Q715mW0n8  Surrender - Martin Jensen Remix
# ...                       ...                              ...
# 32749  3V9tDau6PYa7JEJtOM9tIU                  Chant The Night
# 32750  22M8SqgMTYaDQWV0TeW6Ab                            FIVEg
# 32751  38Zwax8Yu3Y35oxeeohWFK              Rise - Original Mix
# 32752  4xGuK7FsXuZwHCCuNnPzbD                 L'Amour Toujours
# 32753  2Qd1iViAA4do31s4PzGtYM              Duel - Original Mix
#
#           track.artist  track.popularity          track.album.id  \
# 0           Becky Hill                79  7LOS5IWTamBcpqLTdLXFLm
# 1            Lady Gaga                92  4TqgXMSSTwP3RCo3MMSR6t
# ...

# %%
genres['playlist_genre'].unique()
# Out:
# array(['pop', 'rap', 'rock', 'latin', 'r&b', 'edm'], dtype=object)

# %%
genres.rename(columns = {'track.id':'track_id'}, inplace = True)

genres
# Out:
#                      track_id                       track.name  \
# 0      7bIq1v8svANsAys7I694Up  Heaven On My Mind (with Sigala)
# 1      24ySl2hOPGCDcxBxFIqWBu  Rain On Me (with Ariana Grande)
# 2      24Yi9hE78yPEbZ4kxyoXAI            Roses - Imanbek Remix
# 3      3Be7CLdHZpyzsVijme39cW    What's Love Got to Do with It
# 4      57YMEPQhEy5F5Q715mW0n8  Surrender - Martin Jensen Remix
# ...                       ...                              ...
# 32749  3V9tDau6PYa7JEJtOM9tIU                  Chant The Night
# 32750  22M8SqgMTYaDQWV0TeW6Ab                            FIVEg
# 32751  38Zwax8Yu3Y35oxeeohWFK              Rise - Original Mix
# 32752  4xGuK7FsXuZwHCCuNnPzbD                 L'Amour Toujours
# 32753  2Qd1iViAA4do31s4PzGtYM              Duel - Original Mix
#
#           track.artist  track.popularity          track.album.id  \
# 0           Becky Hill                79  7LOS5IWTamBcpqLTdLXFLm
# 1            Lady Gaga                92  4TqgXMSSTwP3RCo3MMSR6t
# ...

# %%
data2=pd.merge(df, genres, on="track_id")

data2
# Out:
#        Unnamed: 0                track_id  \
# 0               0  5aAx2yezTd8zXrkmtKl66Z
# 1               1  5aAx2yezTd8zXrkmtKl66Z
# 2               2  5aAx2yezTd8zXrkmtKl66Z
# 3               3  5aAx2yezTd8zXrkmtKl66Z
# 4               4  5aAx2yezTd8zXrkmtKl66Z
# ...           ...                     ...
# 60255       42158  1f3yAtsJtY87CTmM8RLnxf
# 60256       42158  1f3yAtsJtY87CTmM8RLnxf
# 60257       42159  1f3yAtsJtY87CTmM8RLnxf
# 60258       42159  1f3yAtsJtY87CTmM8RLnxf
# 60259       42159  1f3yAtsJtY87CTmM8RLnxf
#
#                                   track_uri artist_name  \
# 0      spotify:track:5aAx2yezTd8zXrkmtKl66Z  The Weeknd
# 1      spotify:track:5aAx2yezTd8zXrkmtKl66Z  The Weeknd
# 2      spotify:track:5aAx2yezTd8zXrkmtKl66Z  The Weeknd
# 3      spotify:track:5aAx2yezTd8zXrkmtKl66Z  The Weeknd
# 4      spotify:track:5aAx2yezTd8zXrkmtKl66Z  The Weeknd
# ...                                     ...         ...
# 60255  spotify:track:1f3yAtsJtY87CTmM8RLnxf     Nirvana
# ...

# %%
len(data2['track_id'].unique())
# Out:
# 1429

# %%
data=data2

data
# Out:
#        Unnamed: 0                track_id  \
# 0               0  5aAx2yezTd8zXrkmtKl66Z
# 1               1  5aAx2yezTd8zXrkmtKl66Z
# 2               2  5aAx2yezTd8zXrkmtKl66Z
# 3               3  5aAx2yezTd8zXrkmtKl66Z
# 4               4  5aAx2yezTd8zXrkmtKl66Z
# ...           ...                     ...
# 60255       42158  1f3yAtsJtY87CTmM8RLnxf
# 60256       42158  1f3yAtsJtY87CTmM8RLnxf
# 60257       42159  1f3yAtsJtY87CTmM8RLnxf
# 60258       42159  1f3yAtsJtY87CTmM8RLnxf
# 60259       42159  1f3yAtsJtY87CTmM8RLnxf
#
#                                   track_uri artist_name  \
# 0      spotify:track:5aAx2yezTd8zXrkmtKl66Z  The Weeknd
# 1      spotify:track:5aAx2yezTd8zXrkmtKl66Z  The Weeknd
# 2      spotify:track:5aAx2yezTd8zXrkmtKl66Z  The Weeknd
# 3      spotify:track:5aAx2yezTd8zXrkmtKl66Z  The Weeknd
# 4      spotify:track:5aAx2yezTd8zXrkmtKl66Z  The Weeknd
# ...                                     ...         ...
# 60255  spotify:track:1f3yAtsJtY87CTmM8RLnxf     Nirvana
# ...

# %%
data=data2[['track_name','artist_name','Position','Streams','start_week','end_week','playlist_genre','popularity','track_id']]

# %%
data
# Out:
#                     track_name artist_name  Position   Streams  start_week  \
# 0                      Starboy  The Weeknd         1  25286465  2016-12-23
# 1                      Starboy  The Weeknd         1  25734078  2016-12-30
# 2                      Starboy  The Weeknd         3  24261229  2017-01-06
# 3                      Starboy  The Weeknd         4  24480907  2017-01-13
# 4                      Starboy  The Weeknd         5  22925769  2017-01-20
# ...                        ...         ...       ...       ...         ...
# 60255  Smells Like Teen Spirit     Nirvana       181   4949722  2021-01-08
# 60256  Smells Like Teen Spirit     Nirvana       181   4949722  2021-01-08
# 60257  Smells Like Teen Spirit     Nirvana       178   5118391  2021-01-15
# 60258  Smells Like Teen Spirit     Nirvana       178   5118391  2021-01-15
# 60259  Smells Like Teen Spirit     Nirvana       178   5118391  2021-01-15
#
#          end_week playlist_genre  popularity                track_id
# ...

# %%
data.rename(columns = {'playlist_genre':'genre'}, inplace = True)

data
# Out:
# C:\Users\marok\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                     track_name artist_name  Position   Streams  start_week  \
# 0                      Starboy  The Weeknd         1  25286465  2016-12-23
# 1                      Starboy  The Weeknd         1  25734078  2016-12-30
# 2                      Starboy  The Weeknd         3  24261229  2017-01-06
# 3                      Starboy  The Weeknd         4  24480907  2017-01-13
# 4                      Starboy  The Weeknd         5  22925769  2017-01-20
# ...                        ...         ...       ...       ...         ...
# 60255  Smells Like Teen Spirit     Nirvana       181   4949722  2021-01-08
# ...

# %%
data.sort_values(['popularity'])
# Out:
#              track_name      artist_name  Position   Streams  start_week  \
# 3298              Panda        Desiigner        83   5031019  2017-01-13
# 19916  No Hay Nadie Más  Sebastian Yatra       199   3812830  2018-04-13
# 19861           Chun-Li      Nicki Minaj       178   4106695  2018-06-15
# 19860           Chun-Li      Nicki Minaj       118   5291226  2018-06-08
# 19859           Chun-Li      Nicki Minaj       118   5250217  2018-06-01
# ...                 ...              ...       ...       ...         ...
# 52783   Save Your Tears       The Weeknd        92   6323405  2020-04-03
# 52784   Save Your Tears       The Weeknd       119   5463226  2020-04-10
# 52785   Save Your Tears       The Weeknd       164   4814467  2020-04-17
# 52786   Save Your Tears       The Weeknd        28  13229592  2021-01-08
# 52787   Save Your Tears       The Weeknd        15  17274870  2021-01-15
#
#          end_week  genre  popularity                track_id
# ...

# %%
data
# Out:
#                     track_name artist_name  Position   Streams  start_week  \
# 0                      Starboy  The Weeknd         1  25286465  2016-12-23
# 1                      Starboy  The Weeknd         1  25734078  2016-12-30
# 2                      Starboy  The Weeknd         3  24261229  2017-01-06
# 3                      Starboy  The Weeknd         4  24480907  2017-01-13
# 4                      Starboy  The Weeknd         5  22925769  2017-01-20
# ...                        ...         ...       ...       ...         ...
# 60255  Smells Like Teen Spirit     Nirvana       181   4949722  2021-01-08
# 60256  Smells Like Teen Spirit     Nirvana       181   4949722  2021-01-08
# 60257  Smells Like Teen Spirit     Nirvana       178   5118391  2021-01-15
# 60258  Smells Like Teen Spirit     Nirvana       178   5118391  2021-01-15
# 60259  Smells Like Teen Spirit     Nirvana       178   5118391  2021-01-15
#
#          end_week genre  popularity                track_id
# ...

# %%
data.to_csv('cleaned_data.csv', index= False)
